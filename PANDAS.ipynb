# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("zomato_data.csv")
df.head(50)
# Out:
#                                                name online_order book_table  \
# 0                                             Jalsa          Yes        Yes
# 1                                    Spice Elephant          Yes         No
# 2                                   San Churro Cafe          Yes         No
# 3                             Addhuri Udupi Bhojana           No         No
# 4                                     Grand Village           No         No
# 5                                   Timepass Dinner          Yes         No
# 6   Rosewood International Hotel - Bar & Restaurant           No         No
# 7                                            Onesta          Yes        Yes
# 8                                    Penthouse Cafe          Yes         No
# 9                                         Smacznego          Yes         No
# 10                                     Village Café          Yes         No
# 11                                     Cafe Shuffle          Yes        Yes
# 12                                 The Coffee Shack          Yes        Yes
# 13                                       Caf-Eleven           No         No
# 14                                  San Churro Cafe          Yes         No
# 15                                    Cafe Vivacity          Yes         No
# 16                                     Catch-up-ino          Yes         No
# 17                                 Kirthi's Biryani          Yes         No
# 18                                         T3H Cafe           No         No
# 19                    360 Atoms Restaurant And Cafe          Yes         No
# 20                                 The Vintage Cafe          Yes         No
# 21                                     Woodee Pizza          Yes         No
# 22                                  Cafe Coffee Day           No         No
# 23                                     My Tea House          Yes         No
# 24                                    Hide Out Cafe           No         No
# 25                                        CAFE NOVA           No         No
# 26                                     Coffee Tindi          Yes         No
# 27                                   Sea Green Cafe           No         No
# 28                                            Cuppa           No         No
# 29                                 Srinathji's Cafe           No         No
# 30                                        Redberrys          Yes         No
# 31                                       Foodiction          Yes         No
# 32                                      Sweet Truth          Yes         No
# 33                                  Ovenstory Pizza          Yes         No
# 34                                           Faasos          Yes         No
# 35                                  Behrouz Biryani          Yes         No
# 36                                   Fast And Fresh          Yes         No
# 37                                  Szechuan Dragon          Yes         No
# 38                                Empire Restaurant          Yes         No
# 39                     Maruthi Davangere Benne Dosa          Yes         No
# 40                                        Chaatimes          Yes         No
# 41                                     Havyaka Mess           No         No
# 42                                       McDonald's          Yes         No
# 43                                   Domino's Pizza          Yes         No
# 44                                           Onesta          Yes        Yes
# 45                                         Hotboxit           No         No
# 46                                   Kitchen Garden          Yes         No
# 47                                           Recipe          Yes         No
# 48                                    Beijing Bites          Yes         No
# 49                                      Tasty Bytes          Yes         No
#
#      rate  votes  approx_cost(for two people) listed_in(type)
# 0   4.1/5    775                          800          Buffet
# 1   4.1/5    787                          800          Buffet
# 2   3.8/5    918                          800          Buffet
# 3   3.7/5     88                          300          Buffet
# 4   3.8/5    166                          600          Buffet
# 5   3.8/5    286                          600          Buffet
# 6   3.6/5      8                          800          Buffet
# 7   4.6/5   2556                          600           Cafes
# 8   4.0/5    324                          700           other
# 9   4.2/5    504                          550           Cafes
# 10  4.1/5    402                          500           Cafes
# 11  4.2/5    150                          600           Cafes
# 12  4.2/5    164                          500           Cafes
# 13  4.0/5    424                          450           Cafes
# 14  3.8/5    918                          800           Cafes
# 15  3.8/5     90                          650           Cafes
# 16  3.9/5    133                          800           Cafes
# 17  3.8/5    144                          700           Cafes
# 18  3.9/5     93                          300           Cafes
# 19  3.1/5     13                          400           Cafes
# 20  3.0/5     62                          400           Cafes
# 21  3.7/5    180                          500           Cafes
# 22  3.6/5     28                          900           Cafes
# 23  3.6/5     62                          600           Cafes
# 24  3.7/5     31                          300           Cafes
# 25  3.2/5     11                          600           Cafes
# 26  3.8/5     75                          200           Cafes
# 27  3.3/5      4                          500           Cafes
# 28  3.3/5     23                          550           Cafes
# 29  3.8/5    148                          550           Cafes
# 30  4.0/5    219                          600           Cafes
# 31  2.8/5    506                          500           other
# 32  3.9/5     35                          500          Dining
# 33  3.9/5    172                          750          Dining
# 34  4.2/5    415                          500           other
# 35  3.9/5    230                          650          Dining
# 36  2.8/5     91                          400          Dining
# 37  4.2/5   1647                          600          Dining
# 38  4.4/5   4884                          750           other
# 39  4.0/5     17                          150          Dining
# 40  3.8/5    133                          200          Dining
# 41  3.9/5     28                          300          Dining
# 42  3.9/5    286                          500          Dining
# 43  3.9/5    540                          800          Dining
# 44  4.6/5   2556                          600           other
# 45  3.8/5     36                          400          Dining
# 46  3.6/5    244                          300          Dining
# 47  4.0/5    804                          450          Dining
# 48  3.7/5    679                          850          Dining
# 49  3.1/5    245                          300          Dining

# %%
df.describe()
# Out:
#              votes  approx_cost(for two people)
# count   148.000000                   148.000000
# mean    264.810811                   418.243243
# std     653.676951                   223.085098
# min       0.000000                   100.000000
# 25%       6.750000                   200.000000
# 50%      43.500000                   400.000000
# 75%     221.750000                   600.000000
# max    4884.000000                   950.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
print(df["name"].count())
# Out:
# 148

# %%
df[df['votes'] > 500]
# Out:
#                                             name online_order book_table  \
# 0                                          Jalsa          Yes        Yes
# 1                                 Spice Elephant          Yes         No
# 2                                San Churro Cafe          Yes         No
# 7                                         Onesta          Yes        Yes
# 9                                      Smacznego          Yes         No
# 14                               San Churro Cafe          Yes         No
# 31                                    Foodiction          Yes         No
# 37                               Szechuan Dragon          Yes         No
# 38                             Empire Restaurant          Yes         No
# 43                                Domino's Pizza          Yes         No
# 44                                        Onesta          Yes        Yes
# 47                                        Recipe          Yes         No
# 48                                 Beijing Bites          Yes         No
# 53                             Biryanis And More          Yes         No
# 54                                  Roving Feast           No         No
# 55                                     FreshMenu          Yes         No
# 63                               Jeet Restaurant           No        Yes
# 65                                   Kabab Magic          Yes         No
# 67                            Gustoes Beer House           No         No
# 71                              The Biryani Cafe           No         No
# 76   Sri Guru Kottureshwara Davangere Benne Dosa          Yes         No
# 86                                 Meghana Foods          Yes         No
# 145                                 Anna Kuteera          Yes         No
#
#       rate  votes  approx_cost(for two people) listed_in(type)
# 0    4.1/5    775                          800          Buffet
# 1    4.1/5    787                          800          Buffet
# 2    3.8/5    918                          800          Buffet
# 7    4.6/5   2556                          600           Cafes
# 9    4.2/5    504                          550           Cafes
# 14   3.8/5    918                          800           Cafes
# 31   2.8/5    506                          500           other
# 37   4.2/5   1647                          600          Dining
# 38   4.4/5   4884                          750           other
# 43   3.9/5    540                          800          Dining
# 44   4.6/5   2556                          600           other
# 47   4.0/5    804                          450          Dining
# 48   3.7/5    679                          850          Dining
# 53   4.0/5    618                          750          Dining
# 54   4.0/5   1047                          450          Dining
# 55   3.9/5    627                          450          Dining
# 63   4.0/5    808                          850          Dining
# 65   4.1/5   1720                          400          Dining
# 67   4.1/5    868                          700          Dining
# 71   4.1/5    520                          300          Dining
# 76   4.1/5    558                          150          Dining
# 86   4.4/5   4401                          600          Dining
# 145  4.0/5    771                          450          Dining

# %%
df.dtypes
# Out:
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# approx_cost(for two people)     int64
# listed_in(type)                object
# dtype: object

# %%
df.shape
# Out:
# (148, 7)

# %%
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes',
#        'approx_cost(for two people)', 'listed_in(type)'],
#       dtype='object')

# %%
df["name"].replace("Jalsa","Khalsa")
# Out:
# 0                     Khalsa
# 1             Spice Elephant
# 2            San Churro Cafe
# 3      Addhuri Udupi Bhojana
# 4              Grand Village
#                ...
# 143         Melting Melodies
# 144          New Indraprasta
# 145             Anna Kuteera
# 146                   Darbar
# 147            Vijayalakshmi
# Name: name, Length: 148, dtype: object

# %%
df
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# 2                            800          Buffet
# 3                            300          Buffet
# 4                            600          Buffet
# ..                           ...             ...
# 143                          100          Dining
# 144                          150          Dining
# 145                          450          Dining
# 146                          800          Dining
# 147                          200          Dining
#
# [148 rows x 7 columns]

# %%
df.index = df.index +1

# %%
df
# Out:
#                       name online_order book_table   rate  votes  \
# 1                    Jalsa          Yes        Yes  4.1/5    775
# 2           Spice Elephant          Yes         No  4.1/5    787
# 3          San Churro Cafe          Yes         No  3.8/5    918
# 4    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 5            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 144       Melting Melodies           No         No  3.3/5      0
# 145        New Indraprasta           No         No  3.3/5      0
# 146           Anna Kuteera          Yes         No  4.0/5    771
# 147                 Darbar           No         No  3.0/5     98
# 148          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 1                            800          Buffet
# 2                            800          Buffet
# 3                            800          Buffet
# 4                            300          Buffet
# 5                            600          Buffet
# ..                           ...             ...
# 144                          100          Dining
# 145                          150          Dining
# 146                          450          Dining
# 147                          800          Dining
# 148                          200          Dining
#
# [148 rows x 7 columns]

# %%
df[df.dtypes[df.dtypes == "int64"].index]
# Out:
#      votes  approx_cost(for two people)
# 1      775                          800
# 2      787                          800
# 3      918                          800
# 4       88                          300
# 5      166                          600
# ..     ...                          ...
# 144      0                          100
# 145      0                          150
# 146    771                          450
# 147     98                          800
# 148     47                          200
#
# [148 rows x 2 columns]

# %%
df.dtypes[df.dtypes == "int64"]
# Out:
# votes                          int64
# approx_cost(for two people)    int64
# dtype: object

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# name               object
# online_order       object
# book_table         object
# rate               object
# listed_in(type)    object
# dtype: object

# %%
df[df.dtypes[df.dtypes == "object"].index]
# Out:
#                       name online_order book_table   rate listed_in(type)
# 1                    Jalsa          Yes        Yes  4.1/5          Buffet
# 2           Spice Elephant          Yes         No  4.1/5          Buffet
# 3          San Churro Cafe          Yes         No  3.8/5          Buffet
# 4    Addhuri Udupi Bhojana           No         No  3.7/5          Buffet
# 5            Grand Village           No         No  3.8/5          Buffet
# ..                     ...          ...        ...    ...             ...
# 144       Melting Melodies           No         No  3.3/5          Dining
# 145        New Indraprasta           No         No  3.3/5          Dining
# 146           Anna Kuteera          Yes         No  4.0/5          Dining
# 147                 Darbar           No         No  3.0/5          Dining
# 148          Vijayalakshmi          Yes         No  3.9/5          Dining
#
# [148 rows x 5 columns]

# %%
df.iloc[0]          # index based slicing
# Out:
# name                            Jalsa
# online_order                      Yes
# book_table                        Yes
# rate                            4.1/5
# votes                             775
# approx_cost(for two people)       800
# listed_in(type)                Buffet
# Name: 1, dtype: object

# %%
df["NEW_COL"] = 20

# %%
df
# Out:
#                       name online_order book_table   rate  votes  \
# 1                    Jalsa          Yes        Yes  4.1/5    775
# 2           Spice Elephant          Yes         No  4.1/5    787
# 3          San Churro Cafe          Yes         No  3.8/5    918
# 4    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 5            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 144       Melting Melodies           No         No  3.3/5      0
# 145        New Indraprasta           No         No  3.3/5      0
# 146           Anna Kuteera          Yes         No  4.0/5    771
# 147                 Darbar           No         No  3.0/5     98
# 148          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)  NEW_COL
# 1                            800          Buffet       20
# 2                            800          Buffet       20
# 3                            800          Buffet       20
# 4                            300          Buffet       20
# 5                            600          Buffet       20
# ..                           ...             ...      ...
# 144                          100          Dining       20
# 145                          150          Dining       20
# 146                          450          Dining       20
# 147                          800          Dining       20
# 148                          200          Dining       20
#
# [148 rows x 8 columns]

# %%
df["book"] ="DATA SCIENCE"

# %%
df
# Out:
#                       name online_order book_table   rate  votes  \
# 1                    Jalsa          Yes        Yes  4.1/5    775
# 2           Spice Elephant          Yes         No  4.1/5    787
# 3          San Churro Cafe          Yes         No  3.8/5    918
# 4    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 5            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 144       Melting Melodies           No         No  3.3/5      0
# 145        New Indraprasta           No         No  3.3/5      0
# 146           Anna Kuteera          Yes         No  4.0/5    771
# 147                 Darbar           No         No  3.0/5     98
# 148          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)  NEW_COL          book
# 1                            800          Buffet       20  DATA SCIENCE
# 2                            800          Buffet       20  DATA SCIENCE
# 3                            800          Buffet       20  DATA SCIENCE
# 4                            300          Buffet       20  DATA SCIENCE
# 5                            600          Buffet       20  DATA SCIENCE
# ..                           ...             ...      ...           ...
# 144                          100          Dining       20  DATA SCIENCE
# 145                          150          Dining       20  DATA SCIENCE
# 146                          450          Dining       20  DATA SCIENCE
# 147                          800          Dining       20  DATA SCIENCE
# 148                          200          Dining       20  DATA SCIENCE
#
# [148 rows x 9 columns]

# %%
df["name"].duplicated().sum()
# dp = df[df["name"].duplicated()].index
# print(dp)
# Out:
# np.int64(3)

# %%
duplicates = df[df.duplicated(subset='name', keep=False)]
print(duplicates[['name']])
# Out:
#                 name
# 3    San Churro Cafe
# 8             Onesta
# 15   San Churro Cafe
# 26         CAFE NOVA
# 45            Onesta
# 105        CAFE NOVA

# %%
df['votes'].plot(kind='hist')
df.plot(kind='scatter', x='votes', y='approx_cost(for two people)')
# Out:
# <Axes: xlabel='votes', ylabel='approx_cost(for two people)'>
